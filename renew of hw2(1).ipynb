# %%
from google.colab import files
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-25f6e2b5-04c7-4fc0-aac6-fb0574d787f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25f6e2b5-04c7-4fc0-aac6-fb0574d787f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = io.BytesIO(uploaded['DutchAdvert.csv'])

# %%
import pandas as pd
dutch_df = pd.read_csv(uploaded)
dutch_df.head()
# Out:
#    rownames           tv        radio
# 0         1  14000.00585  1954.000000
# 1         2  13304.53320  1952.711914
# 2         3  13342.77929  1859.740112
# 3         4  13571.97558  1922.205932
# 4         5  13163.29492  1836.897705

# %%
dutch_df[['rownames','tv','radio']].value_counts()
# Out:
# rownames  tv           radio
# 1         14000.00585  1954.000000    1
# 153       26865.18359  5712.333984    1
# 142       29248.66992  4059.031250    1
# 143       25935.58007  3864.174560    1
# 144       22060.85937  3798.679443    1
#                                      ..
# 78        14892.96875  3020.474609    1
# 79        14757.48144  2958.286132    1
# 80        16087.08300  3188.611572    1
# 81        16868.57421  3207.875732    1
# 221       75003.94531  9938.024414    1
# Name: count, Length: 221, dtype: int64

# %%
dutch_df.shape
# Out:
# (221, 3)

# %% [markdown]
# There are 221 rows and 3 columns
#
# The columns are all numerical

# %% [markdown]
# Computes the mean, max, and min of the numerical column; TV

# %%
dutch_df.tv.mean()
dutch_df.tv.max()
dutch_df.tv.min()
# Out:
# 9829.551757

# %% [markdown]
# Computes the mean, max, and min of the numerical column; rownames

# %%
dutch_df.rownames.mean()
dutch_df.rownames.max()
dutch_df.rownames.min()
# Out:
# 1

# %% [markdown]
# Computes the mean, max, and min of the numerical column; Radio

# %%
dutch_df.radio.mean()
dutch_df.radio.max()
dutch_df.radio.min()
# Out:
# 1804.861328

# %% [markdown]
# Value counts for each row is used to find if the values are constant or unique
#
# All the columns provide information
#
# All of the columns are constant values

# %%
dutch_df['rownames'].value_counts()
# Out:
# rownames
# 1      1
# 153    1
# 142    1
# 143    1
# 144    1
#       ..
# 78     1
# 79     1
# 80     1
# 81     1
# 221    1
# Name: count, Length: 221, dtype: int64

# %%
dutch_df['tv'].value_counts()
# Out:
# tv
# 14000.00585    1
# 26865.18359    1
# 29248.66992    1
# 25935.58007    1
# 22060.85937    1
#               ..
# 14892.96875    1
# 14757.48144    1
# 16087.08300    1
# 16868.57421    1
# 75003.94531    1
# Name: count, Length: 221, dtype: int64

# %%
dutch_df['radio'].value_counts()
# Out:
# radio
# 1954.000000    1
# 5712.333984    1
# 4059.031250    1
# 3864.174560    1
# 3798.679443    1
#               ..
# 3020.474609    1
# 2958.286132    1
# 3188.611572    1
# 3207.875732    1
# 9938.024414    1
# Name: count, Length: 221, dtype: int64

# %%
dutch_df.hist()
# Out:
# array([[<Axes: title={'center': 'rownames'}>,
#         <Axes: title={'center': 'tv'}>],
#        [<Axes: title={'center': 'radio'}>, <Axes: >]], dtype=object)

# %% [markdown]
# All three of the columns are normally distributed
